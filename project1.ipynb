# %%
# Dependencies
import json
import pandas as pd
import requests
from matplotlib import pyplot as plt 
from config import api_key

# %%
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % api_key}
params = {'location':'Oregon', 'offset':0, 'limit' : 50}
req=requests.get(url, params=params, headers=headers).json()
# Out:
# {'businesses': [{'id': 'gsyqMldeKTBFEmpH41Ku-g',
#    'alias': 'char-portland',
#    'name': 'Char',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UHljcrCy25xastuACQukOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/char-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 80,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 45.49258, 'longitude': -122.60159},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '4144 SE 60th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97206',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['4144 SE 60th Ave', 'Portland, OR 97206']},
#    'phone': '+15034775942',
#    'display_phone': '(503) 477-5942',
#    'distance': 4839.205872986222},
#   {'id': 'a2ncoCQVlstbalrj6s2g3g',
#    'alias': 'taqueria-lindo-michoacan-portland',
#    'name': 'Taqueria Lindo Michoacan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/96HlBD6tJgCxACYvXvUIMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taqueria-lindo-michoacan-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 100,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'foodstands', 'title': 'Food Stands'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 45.5051204661779,
#     'longitude': -122.620531536826},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4035 SE Division St',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97202',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['4035 SE Division St', 'Portland, OR 97202']},
#    'phone': '+15033136864',
#    'display_phone': '(503) 313-6864',
#    'distance': 2872.9971768157566},
#   {'id': '0T8xuGdIZMILGkIo8P8Bhg',
#    'alias': 'original-sub-factory-portland',
#    'name': 'Original Sub Factory',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cOpsBG6HdJLGPxQMf_eh0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/original-sub-factory-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 91,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 45.4771851, 'longitude': -122.5593478},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '10139 SE Foster Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97266',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['10139 SE Foster Rd', 'Portland, OR 97266']},
#    'phone': '+15037886305',
#    'display_phone': '(503) 788-6305',
#    'distance': 8542.815745553826},
#   {'id': 'tFTXWWHE-CeZKsCEJRKbUw',
#    'alias': 'tea-social-portland-3',
#    'name': 'Tea Social',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OI5C6ukCBSxoLJP8jyU2jA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tea-social-portland-3?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 234,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.528536, 'longitude': -122.698369},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '806 NW 23rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97210',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['806 NW 23rd Ave', 'Portland, OR 97210']},
#    'phone': '+15032068541',
#    'display_phone': '(503) 206-8541',
#    'distance': 3731.653306864064},
#   {'id': 'WdRnrHrPdPUc5MWa8pCF9g',
#    'alias': 'sessionable-portland-2',
#    'name': 'Sessionable',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_gxAvD1RdME0THdy8empAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sessionable-portland-2?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 60,
#    'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 45.50456, 'longitude': -122.62645},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3588 SE Division St',
#     'address2': '',
#     'address3': None,
#     'city': 'Portland',
#     'zip_code': '97202',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['3588 SE Division St', 'Portland, OR 97202']},
#    'phone': '+15035014663',
#    'display_phone': '(503) 501-4663',
#    'distance': 2485.3184651614497},
#   {'id': 'bhfzhAnhEbE5ro6aNre8xw',
#    'alias': 'pollo-norte-portland-4',
#    'name': 'Pollo Norte',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SrB_8flAMmjVq2TeHzLMzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pollo-norte-portland-4?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 126,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.52672, 'longitude': -122.63511},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2935 NE Glisan',
#     'address2': None,
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97232',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['2935 NE Glisan', 'Portland, OR 97232']},
#    'phone': '+15037196039',
#    'display_phone': '(503) 719-6039',
#    'distance': 1917.1767238947177},
#   {'id': 'UoYSCam-k_hMmS6OInP9Iw',
#    'alias': 'grand-army-tavern-portland',
#    'name': 'Grand Army Tavern',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/m0dGG1z6aS6qAB4PehxYgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grand-army-tavern-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 91,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 45.5720699, 'longitude': -122.65679},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '901 NE Oneonta St',
#     'address2': '',
#     'address3': None,
#     'city': 'Portland',
#     'zip_code': '97211',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['901 NE Oneonta St', 'Portland, OR 97211']},
#    'phone': '+15038416195',
#    'display_phone': '(503) 841-6195',
#    'distance': 6255.823219198247},
#   {'id': '9hz5Il6RRyGBW7FcwdZtaQ',
#    'alias': 'the-boiling-bowl-portland',
#    'name': 'The Boiling Bowl',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mNlnqDdX2BwuFr7fpB-KgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-boiling-bowl-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 138,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.5237, 'longitude': -122.69475},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '103 NW 21st St',
#     'address2': None,
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97209',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['103 NW 21st St', 'Portland, OR 97209']},
#    'phone': '+19718884255',
#    'display_phone': '(971) 888-4255',
#    'distance': 3272.158162461724},
#   {'id': 'ICtCTow-58Ie24hOC1eG3w',
#    'alias': 'rose-city-taqueria-portland-2',
#    'name': 'Rose City Taqueria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IPw3Ag-pnLNYlOk0VXJc1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rose-city-taqueria-portland-2?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 192,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.5937805, 'longitude': -122.7355118},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '7007 N Fessenden St',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97203',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['7007 N Fessenden St', 'Portland, OR 97203']},
#    'phone': '+15032473333',
#    'display_phone': '(503) 247-3333',
#    'distance': 10736.683236817595},
#   {'id': 'SEdDIeXN4ndpVFQXDAs8ug',
#    'alias': 'stumptown-coffee-roasters-portland-2',
#    'name': 'Stumptown Coffee Roasters',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xepn8ZhzUUJgc5XvpvTDkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stumptown-coffee-roasters-portland-2?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 207,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.5162506, 'longitude': -122.6297531},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3356 SE Belmont St',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97214',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['3356 SE Belmont St', 'Portland, OR 97214']},
#    'phone': '+15032328889',
#    'display_phone': '(503) 232-8889',
#    'distance': 1903.059920529073},
#   {'id': 'vy867RWC_sOHqvdhVwRAlw',
#    'alias': 'brazil-grill-portland',
#    'name': 'Brazil Grill',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FBob41mmMJbo-nUU8t7O9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brazil-grill-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 292,
#    'categories': [{'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 45.51731, 'longitude': -122.68641},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1201 SW 12th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97205',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['1201 SW 12th Ave', 'Portland, OR 97205']},
#    'phone': '+15032220002',
#    'display_phone': '(503) 222-0002',
#    'distance': 2522.0506743549445},
#   {'id': '9_TzJZo3H9ftO2j3syDB6g',
#    'alias': 'marino-adriatic-cafe-portland',
#    'name': 'Marino Adriatic Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BGm26prW7XYzkK8n48jhWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marino-adriatic-cafe-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 99,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 45.5048359930515,
#     'longitude': -122.619780153036},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4129 SE Division St',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97255',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['4129 SE Division St', 'Portland, OR 97255']},
#    'phone': '+15032311313',
#    'display_phone': '(503) 231-1313',
#    'distance': 2933.172879100191},
#   {'id': 'e_GFu6_mI_Y-eMc6hXqPZA',
#    'alias': 'chungdam-korean-fusion-portland',
#    'name': 'Chungdam Korean Fusion',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/5P4PrBDENdDryOhhR_HNIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chungdam-korean-fusion-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 196,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.4975982267464,
#     'longitude': -122.581415846944},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '7901 SE Powell Blvd',
#     'address2': 'Ste A1',
#     'address3': None,
#     'city': 'Portland',
#     'zip_code': '97206',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['7901 SE Powell Blvd',
#      'Ste A1',
#      'Portland, OR 97206']},
#    'phone': '+15032064515',
#    'display_phone': '(503) 206-4515',
#    'distance': 6015.352984664109},
#   {'id': 'swOhj4eTkVbj53UoT9BQOg',
#    'alias': 'fine-goose-portland',
#    'name': 'Fine Goose',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aGJ5K1dv1xdIitXhO5bZFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fine-goose-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 58,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'foodtrucks', 'title': 'Food Trucks'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 45.5590996, 'longitude': -122.6497095},
#    'transactions': ['pickup'],
#    'price': '$',
#    'location': {'address1': 'NE 15th Ave & NE Alberta St',
#     'address2': '',
#     'address3': None,
#     'city': 'Portland',
#     'zip_code': '97211',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['NE 15th Ave & NE Alberta St', 'Portland, OR 97211']},
#    'phone': '+15034987060',
#    'display_phone': '(503) 498-7060',
#    'distance': 4828.514502890229},
#   {'id': '7u0jpnOLHLJUcE2nuHhVCw',
#    'alias': 'sansai-japanese-grill-portland',
#    'name': 'SanSai Japanese Grill',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Vbj925HTr-had65-OB6jNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sansai-japanese-grill-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 428,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 45.52685, 'longitude': -122.69475},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '539 NW 21st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97210',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['539 NW 21st Ave', 'Portland, OR 97210']},
#    'phone': '+19715441500',
#    'display_phone': '(971) 544-1500',
#    'distance': 3384.86922949166},
#   {'id': 'sjKtzUBzMGWRxSD5wZnmTQ',
#    'alias': 'coco-donuts-portland-3',
#    'name': 'Coco Donuts',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rj7xavW1-py9LGoJT4mT1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coco-donuts-portland-3?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 145,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.53535, 'longitude': -122.6373},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2735 NE Broadway St',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97232',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['2735 NE Broadway St', 'Portland, OR 97232']},
#    'phone': '+15034779824',
#    'display_phone': '(503) 477-9824',
#    'distance': 2537.4909943322655},
#   {'id': 'cIwb63lruUYo4u0r8kDfUw',
#    'alias': 'rabbits-cafe-portland',
#    'name': 'Rabbits Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/53bCGuv26DUVuCzi-AdOaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rabbits-cafe-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 76,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 45.524, 'longitude': -122.66},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '115 NE 6th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Portland',
#     'zip_code': '97232',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['115 NE 6th Ave', 'Portland, OR 97232']},
#    'phone': '+15032064512',
#    'display_phone': '(503) 206-4512',
#    'distance': 1003.8174616789521},
#   {'id': 'G_QFLUh-uUat7fCTRBRvNQ',
#    'alias': 'new-deal-cafe-portland',
#    'name': 'New Deal Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/r6aP8TSOg8CBIgqANEcZiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-deal-cafe-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 243,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.5334968566895,
#     'longitude': -122.609001159668},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '5250 NE Halsey St',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97213',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['5250 NE Halsey St', 'Portland, OR 97213']},
#    'phone': '+15035461833',
#    'display_phone': '(503) 546-1833',
#    'distance': 4030.610573854651},
#   {'id': 'JjOoABGI_bODnJzi0pXPxw',
#    'alias': 'noraneko-portland',
#    'name': 'Noraneko',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2VOJStlxPH4Y7mqinXDZPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noraneko-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 441,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 45.512368, 'longitude': -122.665523},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1430 SE Water Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97214',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['1430 SE Water Ave', 'Portland, OR 97214']},
#    'phone': '+15032386356',
#    'display_phone': '(503) 238-6356',
#    'distance': 966.7939057762686},
#   {'id': 'JYK_gPo61ZRCoLRCOIb7Jg',
#    'alias': 'ginos-portland',
#    'name': "Gino's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/t-S4278tbUwx8LuBWbhrWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginos-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 284,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.4648899, 'longitude': -122.65323},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '8051 SE 13th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97202',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['8051 SE 13th Ave', 'Portland, OR 97202']},
#    'phone': '+15032334613',
#    'display_phone': '(503) 233-4613',
#    'distance': 5660.696683314079},
#   {'id': 'cYJ7kq234bJ9WeFNFTpWSQ',
#    'alias': 'tom-yum-thai-cusine-portland',
#    'name': 'Tom Yum Thai Cusine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Yd-kxcEcj0FNocpSsmtz5Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tom-yum-thai-cusine-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 255,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.4796, 'longitude': -122.61817},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4309 SE Woodstock Blvd',
#     'address2': 'Ste 140',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97206',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['4309 SE Woodstock Blvd',
#      'Ste 140',
#      'Portland, OR 97206']},
#    'phone': '+15037880990',
#    'display_phone': '(503) 788-0990',
#    'distance': 4914.923479002315},
#   {'id': 'xDOjijlodmlwjCcFOX-Ysg',
#    'alias': 'jinju-patisserie-portland',
#    'name': 'JinJu Patisserie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3wZ6gkqh6VlomfvDQJXBAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jinju-patisserie-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 59,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'chocolate', 'title': 'Chocolatiers & Shops'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 45.5528625, 'longitude': -122.6668649},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4063 N Williams Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97227',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['4063 N Williams Ave', 'Portland, OR 97227']},
#    'phone': '+15038287728',
#    'display_phone': '(503) 828-7728',
#    'distance': 4253.297210278997},
#   {'id': '6zrW66l7OrmzIxggOHXb5Q',
#    'alias': 'mee-gin-soul-kitchen-portland-2',
#    'name': 'Mee Gin Soul Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1Wv49XmjRNFZu7zu_A_2gA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mee-gin-soul-kitchen-portland-2?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 144,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.51182, 'longitude': -122.62642},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3616 SE Hawthorne Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97214',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['3616 SE Hawthorne Blvd', 'Portland, OR 97214']},
#    'phone': '+15032319898',
#    'display_phone': '(503) 231-9898',
#    'distance': 2199.6589935981574},
#   {'id': 'iO_kgWW11bt3re3FaEnXfw',
#    'alias': '21st-century-pizza-portland',
#    'name': '21st Century Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QodF6sEjnxFE2SuysyYmug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/21st-century-pizza-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 158,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.51684, 'longitude': -122.68675},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1221 SW Jefferson St',
#     'address2': None,
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97201',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['1221 SW Jefferson St', 'Portland, OR 97201']},
#    'phone': '+15039541570',
#    'display_phone': '(503) 954-1570',
#    'distance': 2538.6305984178994},
#   {'id': 'jl319aAtsRKAueSPdwr61A',
#    'alias': 'st-johns-coffee-roasters-portland',
#    'name': 'St Johns Coffee Roasters',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/39RI78GB_4qqbKGiC0HlZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-johns-coffee-roasters-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 92,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 45.5892997, 'longitude': -122.754006},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '7304 N Leavitt Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97203',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['7304 N Leavitt Ave', 'Portland, OR 97203']},
#    'phone': '+15034452249',
#    'display_phone': '(503) 445-2249',
#    'distance': 11283.590969258219},
#   {'id': 'rufqOvxn-3uNIA7mPUjADA',
#    'alias': 'fuel-cafe-portland-3',
#    'name': 'Fuel Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hfxALUaFUndReCNuPOACDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fuel-cafe-portland-3?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 275,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.55894, 'longitude': -122.65049},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1452 NE Alberta St',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97211',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['1452 NE Alberta St', 'Portland, OR 97211']},
#    'phone': '+15033353835',
#    'display_phone': '(503) 335-3835',
#    'distance': 4806.060118367611},
#   {'id': '5_xqpHmri3TXsDcvcCWqRg',
#    'alias': 'quickfish-portland-2',
#    'name': 'QuickFish',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CvmUAxVG8jbvRMm3dR8h_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/quickfish-portland-2?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 198,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'poke', 'title': 'Poke'},
#     {'alias': 'hawaiian', 'title': 'Hawaiian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.5223515990877,
#     'longitude': -122.682814411819},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1122 SW Stark St',
#     'address2': '',
#     'address3': None,
#     'city': 'Portland',
#     'zip_code': '97205',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['1122 SW Stark St', 'Portland, OR 97205']},
#    'phone': '+15034447571',
#    'display_phone': '(503) 444-7571',
#    'distance': 2352.2795584069363},
#   {'id': 'OT7iklmaiTrqa_nHLkuLFg',
#    'alias': 'bar-casa-vale-portland',
#    'name': 'Bar Casa Vale',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QT6lkoBJwmEWhvjQ-ikr6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-casa-vale-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 151,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.52114, 'longitude': -122.65697},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '215 SE 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97214',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['215 SE 9th Ave', 'Portland, OR 97214']},
#    'phone': '+15034779081',
#    'display_phone': '(503) 477-9081',
#    'distance': 652.9068982099499},
#   {'id': 'KcSJPkWL4gmDMjZilelyhw',
#    'alias': 'olive-or-twist-portland',
#    'name': 'Olive or Twist',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/p-x3TlWRzjGdZs0CpY-h_Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/olive-or-twist-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 132,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.5295740067959,
#     'longitude': -122.682431861758},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '925 NW 11th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97209',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['925 NW 11th Ave', 'Portland, OR 97209']},
#    'phone': '+15035462900',
#    'display_phone': '(503) 546-2900',
#    'distance': 2698.1391352537185},
#   {'id': 'T4VUW2wiblDwQG4wJxV91A',
#    'alias': 'my-fathers-place-portland',
#    'name': "My Father's Place",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zd-74PZtW_NfZ6y4fLUp-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/my-fathers-place-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 278,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 45.51888, 'longitude': -122.66108},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '523 SE Grand Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97214',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['523 SE Grand Ave', 'Portland, OR 97214']},
#    'phone': '+15032355494',
#    'display_phone': '(503) 235-5494',
#    'distance': 638.2121211170175},
#   {'id': 'ZQw0aOLOdnNGYWX36yrtRQ',
#    'alias': 'wajan-portland',
#    'name': 'Wajan',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DeEhk7vH8_Yv_oT5rcwiag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wajan-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 83,
#    'categories': [{'alias': 'indonesian', 'title': 'Indonesian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 45.52323, 'longitude': -122.61529},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4611 E Burnside St',
#     'address2': '',
#     'address3': None,
#     'city': 'Portland',
#     'zip_code': '97215',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['4611 E Burnside St', 'Portland, OR 97215']},
#    'phone': '+15032065916',
#    'display_phone': '(503) 206-5916',
#    'distance': 3135.9714108425264},
#   {'id': '7ir-1UF86euZr77zgwgDPg',
#    'alias': 'the-roxy-portland',
#    'name': 'The Roxy',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_aGXU3MAcu1x1a-pkF1YbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-roxy-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 359,
#    'categories': [{'alias': 'tradamerican',
#      'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 45.52256, 'longitude': -122.6824},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1121 SW Stark St',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97205',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['1121 SW Stark St', 'Portland, OR 97205']},
#    'phone': '+15032239160',
#    'display_phone': '(503) 223-9160',
#    'distance': 2337.5400773268025},
#   {'id': 'REJjkCz0JYQCVzsn2MjTDg',
#    'alias': 'bunk-portland-2',
#    'name': 'Bunk',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BvYdgDM-8g05IqhlBebqxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bunk-portland-2?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 204,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.5221868489704,
#     'longitude': -122.677075615915},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '211 SW 6th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97204',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['211 SW 6th Ave', 'Portland, OR 97204']},
#    'phone': '+15033282865',
#    'display_phone': '(503) 328-2865',
#    'distance': 1925.3926316447348},
#   {'id': 'qEDeEKheoTN9G-JtR4n-Iw',
#    'alias': 'paymaster-lounge-portland',
#    'name': 'Paymaster Lounge',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Dm_DEPbggDYAhrVc1wgYiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paymaster-lounge-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 211,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.53047, 'longitude': -122.68828},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1020 NW 17th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97209',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['1020 NW 17th Ave', 'Portland, OR 97209']},
#    'phone': '+15039432780',
#    'display_phone': '(503) 943-2780',
#    'distance': 3119.683154029267},
#   {'id': 'HIWEC4MLGRsusGE4z790Jw',
#    'alias': 'north-45-portland',
#    'name': 'North 45',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/tvW7kSqrF0RP2gS5R_0LHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/north-45-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 301,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 45.5266466, 'longitude': -122.6945208},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '517 NW 21st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97209',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['517 NW 21st Ave', 'Portland, OR 97209']},
#    'phone': '+15032486317',
#    'display_phone': '(503) 248-6317',
#    'distance': 3371.747969825678},
#   {'id': '5ZWTTKeHpGFLSFv9VhSITw',
#    'alias': 'coava-coffee-roasters-portland-2',
#    'name': 'Coava Coffee Roasters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DlZowHofcT5yqohiUhsz3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coava-coffee-roasters-portland-2?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 123,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.5121280915726,
#     'longitude': -122.638650746118},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2631 SE Hawthorne Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97214',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['2631 SE Hawthorne Blvd', 'Portland, OR 97214']},
#    'phone': '+15038948134',
#    'display_phone': '(503) 894-8134',
#    'distance': 1271.631640852235},
#   {'id': 'yd0GklOKNI8QMzKKp4JRrw',
#    'alias': 'cassidys-restaurant-and-bar-portland',
#    'name': "Cassidy's Restaurant and Bar",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Lp7ptLoX4kKo5xfv57eGog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cassidys-restaurant-and-bar-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 192,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.5224977720736,
#     'longitude': -122.685154773659},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1331 SW Washington St',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97205',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['1331 SW Washington St', 'Portland, OR 97205']},
#    'phone': '+15032230054',
#    'display_phone': '(503) 223-0054',
#    'distance': 2530.9901282720675},
#   {'id': 'jQaU3y0s_8wmlBj-nTE5iw',
#    'alias': 'brazilian-house-portland',
#    'name': 'Brazilian House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jLGVjslC1gjSYM_QaLHXsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brazilian-house-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 70,
#    'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#     {'alias': 'brazilian', 'title': 'Brazilian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 45.5165787, 'longitude': -122.6183052},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '4255 SE Belmont St',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97215',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['4255 SE Belmont St', 'Portland, OR 97215']},
#    'phone': '+15036607556',
#    'display_phone': '(503) 660-7556',
#    'distance': 2791.4211277895697},
#   {'id': 'redtRy5AifwLUJpR6u-jeA',
#    'alias': 'tryon-creek-state-park-portland',
#    'name': 'Tryon Creek State Park',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/0FGgF9YjVcIIS3ctQViJzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tryon-creek-state-park-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 66,
#    'categories': [{'alias': 'parks', 'title': 'Parks'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 45.4432, 'longitude': -122.67505},
#    'transactions': [],
#    'location': {'address1': '11321 SW Terwilliger Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97219',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['11321 SW Terwilliger Blvd', 'Portland, OR 97219']},
#    'phone': '+15036364398',
#    'display_phone': '(503) 636-4398',
#    'distance': 8420.573268067143},
#   {'id': '0oMd97xGqGEiX9o1YTs3Cw',
#    'alias': 'cellar-door-coffee-roasters-portland',
#    'name': 'Cellar Door Coffee Roasters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VfpekKi6tFiJRJ0pl4dnJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cellar-door-coffee-roasters-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 120,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.5085334777832,
#     'longitude': -122.654930114746},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2001 SE 11th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97214',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['2001 SE 11th Ave', 'Portland, OR 97214']},
#    'phone': '+15032347155',
#    'display_phone': '(503) 234-7155',
#    'distance': 805.7692731032984},
#   {'id': 'spQDQkRFQdI55NjhpPB2lA',
#    'alias': 'kuangs-kitchen-portland',
#    'name': "Kuang's Kitchen",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/z6slj9hyGkg4oHJg0z76Mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kuangs-kitchen-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 297,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.4448926, 'longitude': -122.727461},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '11137 SW Capitol Hwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97219',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['11137 SW Capitol Hwy', 'Portland, OR 97219']},
#    'phone': '+15032461683',
#    'display_phone': '(503) 246-1683',
#    'distance': 9738.656235376966},
#   {'id': 'WQYd_qTYOyKqxzdpCCY2MA',
#    'alias': 'the-house-of-ramen-portland',
#    'name': 'The House of Ramen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Z-id0GUHs7uW-_1Kohhx7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-house-of-ramen-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 288,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 45.5135244, 'longitude': -122.6773658},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '223 SW Columbia St',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97201',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['223 SW Columbia St', 'Portland, OR 97201']},
#    'phone': '+19712795757',
#    'display_phone': '(971) 279-5757',
#    'distance': 1844.5712625736928},
#   {'id': 'FkbPZRK4nToSX8K0ymx_vA',
#    'alias': 'pieper-cafe-portland',
#    'name': 'Pieper Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KfwJrFHuEvNhr2YEhIvxIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pieper-cafe-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 100,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bagels', 'title': 'Bagels'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 45.4889793395996,
#     'longitude': -122.595718383789},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '6504 SE Foster Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97206',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['6504 SE Foster Rd', 'Portland, OR 97206']},
#    'phone': '+19712717471',
#    'display_phone': '(971) 271-7471',
#    'distance': 5440.9042669936125},
#   {'id': '-oSoAhuGBwGzrN1TTwAIXA',
#    'alias': 'seastar-bakery-portland',
#    'name': 'Seastar Bakery',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dc5csqklQuVvzqJMxXEitw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seastar-bakery-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 85,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 45.5627603083849,
#     'longitude': -122.648887485266},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1603 NE Killingsworth St',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97211',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['1603 NE Killingsworth St', 'Portland, OR 97211']},
#    'phone': '+15032477499',
#    'display_phone': '(503) 247-7499',
#    'distance': 5248.519872573344},
#   {'id': 'PYSXwODSbEHwxB2Np_j3Tg',
#    'alias': 'albina-press-portland-2',
#    'name': 'Albina Press',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ufEN1ORs8EOzyMD0RaHtUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/albina-press-portland-2?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 187,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 45.51179, 'longitude': -122.61126},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '5012 SE Hawthorne Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97215',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['5012 SE Hawthorne Blvd', 'Portland, OR 97215']},
#    'phone': '+15032825214',
#    'display_phone': '(503) 282-5214',
#    'distance': 3371.860870876006},
#   {'id': 'AqHQPyLmXfyADftkmJHXNQ',
#    'alias': 'untapped-portland',
#    'name': 'Untapped',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3LSwuS-nWi3liI1jGpIImg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/untapped-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 56,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 45.5548744, 'longitude': -122.6819763},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4320 N Interstate Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97217',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['4320 N Interstate Ave', 'Portland, OR 97217']},
#    'phone': '+15032064830',
#    'display_phone': '(503) 206-4830',
#    'distance': 4867.583469456293},
#   {'id': 'IivZPgN7tqXWj04DL45PsQ',
#    'alias': 'rontoms-portland-2',
#    'name': 'Rontoms',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/P9jYtqpWB6Y8QEhj4xaCpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rontoms-portland-2?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 404,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 45.522792, 'longitude': -122.659473},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '600 E Burnside St',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97214',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['600 E Burnside St', 'Portland, OR 97214']},
#    'phone': '+15032364536',
#    'display_phone': '(503) 236-4536',
#    'distance': 883.9313011930533},
#   {'id': 'Qm24Wi_TaNvS7Si_DJqS6Q',
#    'alias': 'luce-portland',
#    'name': 'Luce',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PB4wSATeB5sC-G8LZg1dWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luce-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 266,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 45.52264, 'longitude': -122.6437},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2138-2140 E Burnside St',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97214',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['2138-2140 E Burnside St', 'Portland, OR 97214']},
#    'phone': '+15032367195',
#    'display_phone': '(503) 236-7195',
#    'distance': 1120.1451148212236},
#   {'id': 'ivYKnL4zRzklyPq3Hl6vhw',
#    'alias': 'holmans-restaurant-portland',
#    'name': "Holman's Restaurant",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/P4QXJ0rz468K739IqkLTnA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/holmans-restaurant-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 275,
#    'categories': [{'alias': 'divebars', 'title': 'Dive Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 45.5226649, 'longitude': -122.6374149},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '15 SE 28th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97214',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['15 SE 28th Ave', 'Portland, OR 97214']},
#    'phone': '+15032311093',
#    'display_phone': '(503) 231-1093',
#    'distance': 1499.5983393564209},
#   {'id': 'OVNiRWmNJuLHYzN6bIbxSA',
#    'alias': 'alberta-street-market-portland',
#    'name': 'Alberta Street Market',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dBl9Pg2x9anvHCWVZCEf8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/alberta-street-market-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 81,
#    'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 45.55929, 'longitude': -122.65626},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '909 NE Alberta St',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97211',
#     'country': 'US',
#     'state': 'OR',
#     'display_address': ['909 NE Alberta St', 'Portland, OR 97211']},
#    'phone': '+15032822169',
#    'display_phone': '(503) 282-2169',
#    'distance': 4832.916480416914}],
#  'total': 5000,
#  'region': {'center': {'longitude': -122.65411376953125,
#    'latitude': 45.515785397030584}}}

# %%
rest_list = []
for x in req['businesses'] :
    rest_list.append(x['name'])
rest_list
# Out:
# ['Screen Door',
#  'Salt & Straw',
#  'Tasty n Alder',
#  'Mother’s Bistro & Bar',
#  "Pip's Original Doughnuts & Chai",
#  'Pine State Biscuits',
#  'Andina Restaurant',
#  'Blue Star Donuts',
#  'Salt & Straw',
#  'Voodoo Doughnut - Old Town',
#  'Pok Pok',
#  'Salt & Straw',
#  'Deschutes Brewery Portland Public House',
#  'The Waffle Window',
#  'Lúc Lác',
#  'Toro Bravo',
#  'Lechon',
#  "Nong's Khao Man Gai",
#  'Cheryl’s on 12th',
#  'The Observatory',
#  'Le Pigeon',
#  'Portland City Grill',
#  'Ovation Coffee & Tea',
#  'Broder Café',
#  'Pambiche',
#  'Tin Shed',
#  'International Rose Test Garden',
#  'Grassa',
#  'Pine State Biscuits',
#  'Petite Provence',
#  'PDX Sliders',
#  'Tōv',
#  'Blossoming Lotus',
#  'Q Restaurant & Bar',
#  'Apizza Scholls',
#  'Portland Japanese Garden',
#  'Jam On Hawthorne',
#  'Olympia Provisions',
#  'Lardo',
#  'Swiss Hibiscus',
#  'Mediterranean Exploration Company',
#  'Sivalai Thai Restaurant',
#  'Ox',
#  'Ground Kontrol Classic Arcade',
#  'Bamboo Sushi',
#  'Kachka',
#  'Lardo',
#  'Nicholas Restaurant',
#  'Cuon - Vietnamese Street Food',
#  'Gravy']

# %%
rest_df = pd.DataFrame({'Name': rest_list, 'Review_Count': '' , 'Rating': '', 'Price': ''})
rest_df
# Out:
#                                        Name Review_Count Rating Price
# 0                               Screen Door
# 1                              Salt & Straw
# 2                             Tasty n Alder
# 3                     Mother’s Bistro & Bar
# 4           Pip's Original Doughnuts & Chai
# 5                       Pine State Biscuits
# 6                         Andina Restaurant
# 7                          Blue Star Donuts
# 8                              Salt & Straw
# 9                Voodoo Doughnut - Old Town
# 10                                  Pok Pok
# 11                             Salt & Straw
# 12  Deschutes Brewery Portland Public House
# 13                        The Waffle Window
# 14                                  Lúc Lác
# 15                               Toro Bravo
# 16                                   Lechon
# 17                      Nong's Khao Man Gai
# 18                         Cheryl’s on 12th
# 19                          The Observatory
# 20                                Le Pigeon
# 21                      Portland City Grill
# 22                     Ovation Coffee & Tea
# 23                              Broder Café
# 24                                 Pambiche
# 25                                 Tin Shed
# 26           International Rose Test Garden
# 27                                   Grassa
# 28                      Pine State Biscuits
# 29                          Petite Provence
# 30                              PDX Sliders
# 31                                      Tōv
# 32                         Blossoming Lotus
# 33                       Q Restaurant & Bar
# 34                           Apizza Scholls
# 35                 Portland Japanese Garden
# 36                         Jam On Hawthorne
# 37                       Olympia Provisions
# 38                                    Lardo
# 39                           Swiss Hibiscus
# 40        Mediterranean Exploration Company
# 41                  Sivalai Thai Restaurant
# 42                                       Ox
# 43            Ground Kontrol Classic Arcade
# 44                             Bamboo Sushi
# 45                                   Kachka
# 46                                    Lardo
# 47                      Nicholas Restaurant
# 48            Cuon - Vietnamese Street Food
# 49                                    Gravy

# %%
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % api_key}
params = {'location':'Oregon', 'limit' : 50}

params['offset'] = 0
for index, row in rest_df.iterrows():
    req=requests.get(url, params=params, headers=headers).json()
    
    
    rest_df.loc[index, "Review_Count"] = req["businesses"][0]["review_count"]
    #rest_df.loc[index, "Categories"] = req["businesses"][0]["categories"]
    rest_df.loc[index, "Rating"] = req["businesses"][0]["rating"]
    rest_df.loc[index, "Price"] = req["businesses"][0]["price"]
    
rest_df
