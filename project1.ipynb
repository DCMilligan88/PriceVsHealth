# %%
# Dependencies
import json
import pandas as pd
import requests
from matplotlib import pyplot as plt 
from config import api_key
from pprint import pprint

# %%
inspection_df = pd.read_csv('InspectionOnlyPortland.csv')
inspection_df = inspection_df.sort_values('Name')# = inspection_df.drop_duplicates('Name')

# %%
inspection_df
# Out:
#                            Name       Score                      Address  \
# 524   10 Barrel Brewing Company   95.500000          1411 NW Flanders St
# 173             108 Bar N Grill   98.750000           10845 NE Halsey St
# 2169                 13 Virtues   91.000000        6410 SE Milwaukie Ave
# 612        15th Avenue Hophouse   98.500000            1517 NE Brazee St
# 800        1st United Methodist  100.000000         1838 SW Jefferson St
# ...                         ...         ...                          ...
# 2596                      Zenbu   93.666667             8609 SE 17th Ave
# 2511               Zero Degrees   93.250000  8220 SE Harrison St STE 115
# 1970       Zien Hong Restaurant   92.333333           5314 NE Sandy Blvd
# 774                  Zilla Sake   97.000000           1806 NE Alberta St
# 2034  Zoiglhaus Brewing Company   86.666667             5716 SE 92nd Ave
#
#           City      Zip
# 524   Portland  97209.0
# 173   Portland  97220.0
# ...

# %%
inspection_df['Rating'] = ''
inspection_df['Review Count'] = ''
inspection_df['Price'] = ''
inspection_df['Yelp Name'] = ''
inspection_df = inspection_df.reset_index()
del inspection_df['index']

# %%
inspection_df
# Out:
#                            Name       Score                      Address  \
# 0     10 Barrel Brewing Company   95.500000          1411 NW Flanders St
# 1               108 Bar N Grill   98.750000           10845 NE Halsey St
# 2                    13 Virtues   91.000000        6410 SE Milwaukie Ave
# 3          15th Avenue Hophouse   98.500000            1517 NE Brazee St
# 4          1st United Methodist  100.000000         1838 SW Jefferson St
# ...                         ...         ...                          ...
# 2741                      Zenbu   93.666667             8609 SE 17th Ave
# 2742               Zero Degrees   93.250000  8220 SE Harrison St STE 115
# 2743       Zien Hong Restaurant   92.333333           5314 NE Sandy Blvd
# 2744                 Zilla Sake   97.000000           1806 NE Alberta St
# 2745  Zoiglhaus Brewing Company   86.666667             5716 SE 92nd Ave
#
#           City      Zip Rating Review Count Price Yelp Name
# 0     Portland  97209.0
# ...

# %%
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % api_key}
params = {'location': 'Portland'}
counter = 0
# iterating through inspection_df
for index, row in inspection_df.iterrows():
    
    #creating variables to call in our api search
    zipc = row['Zip']
    city_rest = row['City']
    address_rest = row['Address']
    term = row['Name']
    #params['location'] = f'{address_rest},{city_rest},{zipc}'
    params['term'] = term
    response = requests.get(url, headers=headers, params=params).json()
    
    #try to populate the rest of dataframe
    try:
        results = response['businesses']
        inspection_df.loc[index, 'Rating'] = results[0]['rating']
        inspection_df.loc[index, 'Review Count'] = results[0]['review_count']
        inspection_df.loc[index, 'price'] = results[0]['price']
        inspection_df.loc[index, 'Yelp Name'] = results[0]['name']
    except:
        print("error... skipping")
# Out:
# error... skipping
# error... skipping
# error... skipping
# error... skipping
# error... skipping
# error... skipping
# error... skipping
# error... skipping
# error... skipping
# error... skipping
# error... skipping
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-25b26464e07a> in <module>
#      13     #params['location'] = f'{address_rest},{city_rest},{zipc}'
#      14     params['term'] = term
# ---> 15     response = requests.get(url, headers=headers, params=params).json()
#      16
#      17     #try to populate the rest of dataframe
#
# c:\users\dcmil\anaconda3\envs\pythondata\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ...

# %%
params = {'location': '0315 SW Montgomery St 120, Portland, 97220'}
response = requests.get(url, headers=headers, params=params).json()
response

# %%
del inspection_df['Price']

# %%
inspection_df

# %%
inspection_df.dropna()

# %%
inspection_df
