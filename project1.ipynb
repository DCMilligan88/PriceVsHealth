# %%
# Dependencies
import json
import pandas as pd
import requests
from matplotlib import pyplot as plt 
from config import api_key

# %%
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % api_key}
params = {'location':'Oregon', 'offset':0, 'limit' : 50}
req=requests.get(url, params=params, headers=headers).json()

# %%
rest_list = []
for x in req['businesses'] :
    rest_list.append(x['name'])
rest_list
# Out:
# ['Screen Door',
#  'Salt & Straw',
#  'Tasty n Alder',
#  'Mother’s Bistro & Bar',
#  "Pip's Original Doughnuts & Chai",
#  'Pine State Biscuits',
#  'Andina Restaurant',
#  'Blue Star Donuts',
#  'Salt & Straw',
#  'Voodoo Doughnut - Old Town',
#  'Pok Pok',
#  'Salt & Straw',
#  'Deschutes Brewery Portland Public House',
#  'The Waffle Window',
#  'Lúc Lác',
#  'Toro Bravo',
#  'Lechon',
#  "Nong's Khao Man Gai",
#  'Cheryl’s on 12th',
#  'The Observatory',
#  'Le Pigeon',
#  'Portland City Grill',
#  'Ovation Coffee & Tea',
#  'Broder Café',
#  'Pambiche',
#  'Tin Shed',
#  'International Rose Test Garden',
#  'Grassa',
#  'Pine State Biscuits',
#  'Petite Provence',
#  'PDX Sliders',
#  'Tōv',
#  'Blossoming Lotus',
#  'Q Restaurant & Bar',
#  'Apizza Scholls',
#  'Portland Japanese Garden',
#  'Jam On Hawthorne',
#  'Olympia Provisions',
#  'Lardo',
#  'Mediterranean Exploration Company',
#  'Sivalai Thai Restaurant',
#  'Ox',
#  'Ground Kontrol Classic Arcade',
#  'Kachka',
# ...

# %%
rest_df = pd.DataFrame({'Name': rest_list, 'Review_Count': '' , 'Rating': '', 'Price': ''})
rest_df
# Out:
#                                        Name Review_Count Rating Price
# 0                               Screen Door
# 1                              Salt & Straw
# 2                             Tasty n Alder
# 3                     Mother’s Bistro & Bar
# 4           Pip's Original Doughnuts & Chai
# 5                       Pine State Biscuits
# 6                         Andina Restaurant
# 7                          Blue Star Donuts
# 8                              Salt & Straw
# 9                Voodoo Doughnut - Old Town
# 10                                  Pok Pok
# 11                             Salt & Straw
# 12  Deschutes Brewery Portland Public House
# 13                        The Waffle Window
# 14                                  Lúc Lác
# 15                               Toro Bravo
# 16                                   Lechon
# 17                      Nong's Khao Man Gai
# 18                         Cheryl’s on 12th
# 19                          The Observatory
# ...

# %%
inspection_df = pd.read_csv('InspectionOnlyPortland.csv')
inspection_df
# Out:
#                                                  Name       Score  \
# 0     McCormick and Schmicks Harborside at the Marina   93.250000
# 1                                          Yomi Sushi   97.333333
# 2                                     Upstream Coffee   95.000000
# 3                                   Little River Cafe  100.000000
# 4                                         IL Terrazzo   91.000000
# ...                                               ...         ...
# 2741        Aloft Portland Airport at Cascade Station   97.750000
# 2742                           Parkstone Wood Kitchen   93.333333
# 2743                  Country Inn & Suites by Carlson   99.250000
# 2744                                  Club 205 Tavern   95.666667
# 2745                               The Venue - Falcos  100.000000
#
#                               Address      City      Zip
# 0               0309 SW Montgomery St  Portland  97201.0
# 1           0315 SW Montgomery St 120  Portland  97201.0
# ...

# %%
inspection_df['Rating'] = ''
inspection_df['Review Count'] = ''
inspection_df['Price'] = ''
inspection_df
# Out:
#                                                  Name       Score  \
# 0     McCormick and Schmicks Harborside at the Marina   93.250000
# 1                                          Yomi Sushi   97.333333
# 2                                     Upstream Coffee   95.000000
# 3                                   Little River Cafe  100.000000
# 4                                         IL Terrazzo   91.000000
# ...                                               ...         ...
# 2741        Aloft Portland Airport at Cascade Station   97.750000
# 2742                           Parkstone Wood Kitchen   93.333333
# 2743                  Country Inn & Suites by Carlson   99.250000
# 2744                                  Club 205 Tavern   95.666667
# 2745                               The Venue - Falcos  100.000000
#
#                               Address      City      Zip Rating Review Count  \
# 0               0309 SW Montgomery St  Portland  97201.0
# ...

# %%
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % api_key}
params = {}
counter = 0
for index, row in inspection_df.iterrows():
    zipc = row['Zip']
    city_rest = row['City']
    address_rest = row['Address']
    params['location'] = f'{address_rest},{city_rest},{zipc}'

# %%
params = {'location': '0315 SW Montgomery St 120, Portland, 97220'}
response = requests.get(url, headers=headers, params=params).json()
response
# Out:
# {'businesses': [{'id': 'n73rxa6e6-fTIxQzfv4BuA',
#    'alias': 'mother-s-bistro-and-bar-portland',
#    'name': 'Mother’s Bistro & Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sLEpdghl_XDzRYK_TAWWzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mother-s-bistro-and-bar-portland?adjust_creative=P-cfy5pFYtKjTrOgBrwZXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=P-cfy5pFYtKjTrOgBrwZXQ',
#    'review_count': 4399,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 45.522196, 'longitude': -122.673868},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '121 SW 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Portland',
#     'zip_code': '97204',
#     'country': 'US',
# ...
