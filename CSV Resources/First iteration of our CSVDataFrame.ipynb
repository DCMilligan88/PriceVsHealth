# %%
import json
import pandas as pd
import requests
from matplotlib import pyplot as plt 
from config import api_key

# %%
inspection_1st = pd.read_csv('CSV_1_29_20.csv')

# %%
inspection_1st
# Out:
#                                                  Name       Score  \
# 0     McCormick and Schmicks Harborside at the Marina   93.250000
# 1                                          Yomi Sushi   97.333333
# 2                                     Upstream Coffee   95.000000
# 3                                   Little River Cafe  100.000000
# 4                                         IL Terrazzo   91.000000
# ...                                               ...         ...
# 3164        Aloft Portland Airport at Cascade Station   97.750000
# 3165                           Parkstone Wood Kitchen   93.333333
# 3166                  Country Inn & Suites by Carlson   99.250000
# 3167                                  Club 205 Tavern   95.666667
# 3168                               The Venue - Falcos  100.000000
#
#                               Address      City      Zip
# 0               0309 SW Montgomery St  Portland  97201.0
# 1           0315 SW Montgomery St 120  Portland  97201.0
# ...
